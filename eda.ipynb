# %%
# Import necessary libraries
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df= pd.read_csv('Loan_Default.csv')

# %%
df.head()
# Out:
#       ID  year loan_limit             Gender approv_in_adv loan_type  \
# 0  24890  2019         cf  Sex Not Available         nopre     type1
# 1  24891  2019         cf               Male         nopre     type2
# 2  24892  2019         cf               Male           pre     type1
# 3  24893  2019         cf               Male         nopre     type1
# 4  24894  2019         cf              Joint           pre     type1
#
#   loan_purpose Credit_Worthiness open_credit business_or_commercial  ...  \
# 0           p1                l1        nopc                  nob/c  ...
# 1           p1                l1        nopc                    b/c  ...
# 2           p1                l1        nopc                  nob/c  ...
# 3           p4                l1        nopc                  nob/c  ...
# 4           p1                l1        nopc                  nob/c  ...
#
#    credit_type  Credit_Score  co-applicant_credit_type    age  \
# ...

# %%
df.describe()
# Out:
#                   ID      year   loan_amount  rate_of_interest  \
# count  148670.000000  148670.0  1.486700e+05     112231.000000
# mean    99224.500000    2019.0  3.311177e+05          4.045476
# std     42917.476598       0.0  1.839093e+05          0.561391
# min     24890.000000    2019.0  1.650000e+04          0.000000
# 25%     62057.250000    2019.0  1.965000e+05          3.625000
# 50%     99224.500000    2019.0  2.965000e+05          3.990000
# 75%    136391.750000    2019.0  4.365000e+05          4.375000
# max    173559.000000    2019.0  3.576500e+06          8.000000
#
#        Interest_rate_spread  Upfront_charges           term  property_value  \
# count         112031.000000    109028.000000  148629.000000    1.335720e+05
# mean               0.441656      3224.996127     335.136582    4.978935e+05
# std                0.513043      3251.121510      58.409084    3.599353e+05
# min               -3.638000         0.000000      96.000000    8.000000e+03
# ...

# %%
pd.set_option('display.max_columns', None)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 148670 entries, 0 to 148669
# Data columns (total 34 columns):
#  #   Column                     Non-Null Count   Dtype
# ---  ------                     --------------   -----
#  0   ID                         148670 non-null  int64
#  1   year                       148670 non-null  int64
#  2   loan_limit                 145326 non-null  object
#  3   Gender                     148670 non-null  object
#  4   approv_in_adv              147762 non-null  object
#  5   loan_type                  148670 non-null  object
#  6   loan_purpose               148536 non-null  object
#  7   Credit_Worthiness          148670 non-null  object
#  8   open_credit                148670 non-null  object
#  9   business_or_commercial     148670 non-null  object
#  10  loan_amount                148670 non-null  int64
#  11  rate_of_interest           112231 non-null  float64
#  12  Interest_rate_spread       112031 non-null  float64
# ...

# %%
df['Status']
# Out:
# 0         1
# 1         1
# 2         0
# 3         0
# 4         0
#          ..
# 148665    0
# 148666    0
# 148667    0
# 148668    0
# 148669    0
# Name: Status, Length: 148670, dtype: int64

# %%
numeric_cols = df.select_dtypes(include=['number']).columns
print("Numeric columns:\n", numeric_cols)
# Out:
# Numeric columns:
#  Index(['ID', 'year', 'loan_amount', 'rate_of_interest', 'Interest_rate_spread',
#        'Upfront_charges', 'term', 'property_value', 'income', 'Credit_Score',
#        'LTV', 'Status', 'dtir1'],
#       dtype='object')

# %%
df['Status'].value_counts().plot(kind='bar', color=['#FF9999', '#66B3FF'])
plt.title('Loan Status Distribution')
# Out:
# Text(0.5, 1.0, 'Loan Status Distribution')

# %%
# Find and display the count of null values in each column
null_values = df.isnull().sum()
print("Null values in each column:\n", null_values)
# Out:
# Null values in each column:
#  ID                               0
# year                             0
# loan_limit                    3344
# Gender                           0
# approv_in_adv                  908
# loan_type                        0
# loan_purpose                   134
# Credit_Worthiness                0
# open_credit                      0
# business_or_commercial           0
# loan_amount                      0
# rate_of_interest             36439
# Interest_rate_spread         36639
# Upfront_charges              39642
# term                            41
# Neg_ammortization              121
# interest_only                    0
# lump_sum_payment                 0
# property_value               15098
# construction_type                0
# occupancy_type                   0
# Secured_by                       0
# total_units                      0
# income                        9150
# credit_type                      0
# Credit_Score                     0
# ...

# %%
# Fill null values with appropriate values
# For numerical columns, fill with the mean
# For categorical columns, fill with the mode
for column in df.columns:
    if df[column].dtype in ['int64', 'float64']:
        df[column].fillna(df[column].mean(), inplace=True)
    else:
        df[column].fillna(df[column].mode()[0], inplace=True)


print("Null values after filling:\n", df.isnull().sum())
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_10656\1067189376.py:6: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[column].fillna(df[column].mean(), inplace=True)
# C:\Users\HP\AppData\Local\Temp\ipykernel_10656\1067189376.py:8: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# ...

# %%
numeric_df = df.select_dtypes(include=['int64', 'float64'])

# %%
# Compute correlation matrix (numeric features)
corr = numeric_df.corr()
#correlation matrix
plt.figure(figsize=(10, 8))
sns.heatmap(corr, cmap='coolwarm', annot=True, fmt=".2f", linewidths=0.5)
plt.title("Correlation Matrix")
plt.show()

# %% [markdown]
# The correlation matrix (`corr`) provides insights into the relationships between numerical variables in the dataset. Here's what it shows:
#
# 1. **Strong Positive Correlations**:
#     - `loan_amount` and `property_value` (0.688): Indicates that higher loan amounts are associated with higher property values.
#     - `rate_of_interest` and `Interest_rate_spread` (0.614): Suggests that as the interest rate increases, the spread also tends to increase.
#
# 2. **Moderate Positive Correlations**:
#     - `term` and `dtir1` (0.104): Indicates a slight positive relationship between loan term and debt-to-income ratio.
#     - `LTV` and `dtir1` (0.072): Suggests a weak positive relationship between loan-to-value ratio and debt-to-income ratio.
#
# 3. **Negative Correlations**:
#     - `property_value` and `LTV` (-0.215): Indicates that higher property values are associated with lower loan-to-value ratios.
#     - `income` and `dtir1` (-0.253): Suggests that higher incomes are associated with lower debt-to-income ratios.
#
# 4. **Weak or No Correlation**:
#     - Many variables, such as `Credit_Score` and `loan_amount`, show very weak or no significant correlation with other variables.
#
# ### Key Takeaways:
# - The matrix helps identify relationships that could be useful for predictive modeling or understanding trends in the data.
# - Strong correlations (positive or negative) can indicate potential dependencies or patterns between variables.
# - Weak correlations suggest little to no linear relationship between the variables.

# %%
df.drop(['ID', 'year'], axis=1, inplace=True)
