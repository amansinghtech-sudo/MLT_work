# %%
import pandas as pd

#loading the full dataset of around 1.2 GB
full_df = pd.read_csv('loan.csv')
# Out:
# /tmp/ipykernel_14877/1999005249.py:3: DtypeWarning: Columns (19,47,55,112,123,124,125,128,129,130,133,139,140,141) have mixed types. Specify dtype option on import or set low_memory=False.
#   full_df = pd.read_csv('loan.csv')

# %%
from sklearn.model_selection import train_test_split

sample_df,_ = train_test_split(full_df, test_size=0.98,stratify= full_df['loan_status'], random_state=42) #keep around 2% of the data
#saving the sample dataset to a csv file
sample_df.to_csv('sample_loan.csv', index=False)

# %%
df = pd.read_csv('sample_loan.csv')
df.describe()
# Out:
# /tmp/ipykernel_14877/2445161314.py:1: DtypeWarning: Columns (123,124,125,128,129,130,133) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('sample_loan.csv')
#         id  member_id     loan_amnt   funded_amnt  funded_amnt_inv  \
# count  0.0        0.0  45213.000000  45213.000000     45213.000000
# mean   NaN        NaN  15001.848473  14995.971844     14977.970368
# std    NaN        NaN   9198.803442   9196.583892      9199.413553
# min    NaN        NaN   1000.000000   1000.000000         0.000000
# 25%    NaN        NaN   8000.000000   8000.000000      8000.000000
# 50%    NaN        NaN  12800.000000  12800.000000     12800.000000
# 75%    NaN        NaN  20000.000000  20000.000000     20000.000000
# max    NaN        NaN  40000.000000  40000.000000     40000.000000
#
#            int_rate   installment    annual_inc  url           dti  ...  \
# count  45213.000000  45213.000000  4.521300e+04  0.0  45176.000000  ...
# ...

# %%
df.info()
print(df)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45213 entries, 0 to 45212
# Columns: 145 entries, id to settlement_term
# dtypes: float64(105), int64(4), object(36)
# memory usage: 50.0+ MB
#        id  member_id  loan_amnt  funded_amnt  funded_amnt_inv        term  \
# 0     NaN        NaN       5250         5250           5250.0   36 months
# 1     NaN        NaN      21525        21525          21525.0   60 months
# 2     NaN        NaN      20000        20000          20000.0   36 months
# 3     NaN        NaN      10000        10000          10000.0   36 months
# 4     NaN        NaN      29000        29000          29000.0   36 months
# ...    ..        ...        ...          ...              ...         ...
# 45208 NaN        NaN      35000        35000          35000.0   36 months
# 45209 NaN        NaN      10000        10000          10000.0   36 months
# 45210 NaN        NaN      15000        15000          15000.0   36 months
# ...

# %%
df['loan_status'].value_counts()
#checking the missing values
# Out:
# loan_status
# Fully Paid                                             20839
# Current                                                18394
# Charged Off                                             5233
# Late (31-120 days)                                       438
# In Grace Period                                          179
# Late (16-30 days)                                         75
# Does not meet the credit policy. Status:Fully Paid        40
# Does not meet the credit policy. Status:Charged Off       15
# Name: count, dtype: int64

# %%
df.isnull()
# Out:
#          id  member_id  loan_amnt  funded_amnt  funded_amnt_inv   term  \
# 0      True       True      False        False            False  False
# 1      True       True      False        False            False  False
# 2      True       True      False        False            False  False
# 3      True       True      False        False            False  False
# 4      True       True      False        False            False  False
# ...     ...        ...        ...          ...              ...    ...
# 45208  True       True      False        False            False  False
# 45209  True       True      False        False            False  False
# 45210  True       True      False        False            False  False
# 45211  True       True      False        False            False  False
# 45212  True       True      False        False            False  False
#
#        int_rate  installment  grade  sub_grade  ...  \
# 0         False        False  False      False  ...
# ...
